# %% [markdown]
# ## CASE STUDY HEALTHCARE DATA ANALYSIS

# %% [markdown]
# ### BUSINESS CONTEXT:
#
# #### The Cloudera Data Science Challenge is a rigorous competition in which candidates must provide a solution to a real-world big data problem that surpasses a benchmark specified by some of the world's elite data scientists,
#
# #### In the U.S., Medicare reimburses private providers for medical procedures performed for covered individuals. As such, it needs to verify that the type of procedures performed and the cost of those procedures are consistent and reasonable. Finally, it needs to detect possible errors or fraud in claims for reimbursement from providers. You have been hired to analyze a large amount of data from Medicare and try to detect abnormal data - providers, areas, or patients with unusual procedures and/or claims.
#
# #### The objective of the Cloudera Data Science Challenge 2 was to uncover anomalous patients, procedures, providers, and regions in the United States government's Medicare health insurance system.

# %% [markdown]
# ### PROBLEM SUMMARY:
#
# ### The Challenge was divided into the following three parts, each of which had specific requirements that pertained to identifying anomalous entities in different aspects of the Medicare system:

# %% [markdown]
# ### PART 1 : Identify providers that overcharge for certain procedures or regions where procedures are too expensive.

# %%
#Importing necessary Libraries
import pandas as pd
import numpy as np
import math

# %%
#Importing necessary Datasets from the folder
Medicare_Charge_In = pd.read_csv("E:Datasets/Medicare_Charge_Inpatient_DRG100_DRG_Summary_by_DRG_FY2011.csv")
Medicare_Charge_Out = pd.read_csv("E:Datasets/Medicare_Charge_Outpatient_APC30_Summary_by_APC_CY2011.csv")
Medicare_Provider_Charge_In = pd.read_csv("E:Datasets/Medicare_Provider_Charge_Inpatient_DRG100_FY2011.csv")
Medicare_Provider_Charge_Out = pd.read_csv("E:Datasets/Medicare_Provider_Charge_Outpatient_APC30_CY2011_v2.csv")
Patient_history = pd.read_csv("E:Datasets/Patient_history_samp.csv")
Review_patient = pd.read_csv("E:Datasets/Review_patient_history_samp.csv")
Rreview_transaction = pd.read_csv("E:Datasets/Rreview_transaction_coo.csv")
Transaction= pd.read_csv("E:Datasets/Transaction_coo.csv")

# %% [markdown]
# ### Data Analysis and Data Preparation :

# %% [markdown]
# #### The Data Analysis will be based on financial summary data from 2011 that were made availible by the centers of  Medicare and Medicaid Services
# #### Data
# - Medicare_Provider_Charge_Inpatient_DRG100_FY2011.csv
# - Medicare_Provider_Charge_Outpatient_APC30_CY2011_v2.csv

# %%
Medicare_Provider_Charge_In.head(2)
# Out:
#                              DRG Definition  Provider Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
#
#                       Provider Name     Provider Street Address Provider City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
#
#   Provider State  Provider Zip Code  \
# 0             AL              36301
# 1             AL              35957
#
#   Hospital Referral Region (HRR) Description  Total Discharges  \
# 0                                AL - Dothan                91
# 1                            AL - Birmingham                14
#
#    Average Covered Charges  Average Total Payments  Average Medicare Payments
# 0              32963.07692             5777.241758                4763.736264
# 1              15131.85714             5787.571429                4976.714286

# %%
Medicare_Provider_Charge_Out.head(2)
# Out:
#                                         APC  Provider Id  \
# 0  0012 - Level I Debridement & Destruction        10029
# 1  0012 - Level I Debridement & Destruction        20024
#
#                          Provider Name Provider Street Address Provider City  \
# 0  EAST ALABAMA MEDICAL CENTER AND SNF  2000 PEPPERELL PARKWAY       OPELIKA
# 1   CENTRAL PENINSULA GENERAL HOSPITAL      250 HOSPITAL PLACE      SOLDOTNA
#
#   Provider State  Provider Zip Code  \
# 0             AL              36801
# 1             AK              99669
#
#   Hospital Referral Region (HRR) Description  Outpatient Services  \
# 0                            AL - Birmingham                   23
# 1                             AK - Anchorage                  994
#
#    Average  Estimated Submitted Charges  Average Total Payments
# 0                             78.086957               21.910435
# 1                            149.589749               36.623853

# %%
Medicare_Provider_Charge_In.isnull().any()
# Out:
# DRG Definition                                False
# Provider Id                                   False
# Provider Name                                 False
# Provider Street Address                       False
# Provider City                                 False
# Provider State                                False
# Provider Zip Code                             False
# Hospital Referral Region (HRR) Description    False
# Total Discharges                              False
# Average Covered Charges                       False
# Average Total Payments                        False
# Average Medicare Payments                     False
# dtype: bool

# %%
Medicare_Provider_Charge_Out.isnull().any()
# Out:
# APC                                           False
# Provider Id                                   False
# Provider Name                                 False
# Provider Street Address                       False
# Provider City                                 False
# Provider State                                False
# Provider Zip Code                             False
# Hospital Referral Region (HRR) Description    False
# Outpatient Services                           False
# Average  Estimated Submitted Charges          False
# Average Total Payments                        False
# dtype: bool

# %% [markdown]
# ####  Part1A - Highest Cost Variation
# The Highest cost variation can be calculated by dividing the standard deviation by the mean.
#
# The cost variation of OutpatientsAPCs overtakes the cost variation of InpatientsDRG.
# The 3 Highest cost variation (not the highest cost of procedure) can be seen in Outpatients for follwing APCS-
#
# - 0604 - Level 1 Hospital Clinic Visits
# - 0698 - Level II Eye Tests & Treatments
# - 0019 - Level I Excision/ Biopsy

# %%
# Finding Standard deviation and mean for InpatientDRG
Medicare_IN = pd.concat(
[Medicare_Provider_Charge_In[['DRG Definition','Average Covered Charges']].groupby(['DRG Definition']).agg('std').add_suffix('_std'),
 Medicare_Provider_Charge_In[['DRG Definition','Average Covered Charges']].groupby(['DRG Definition']).agg('mean').add_suffix('_avg')]
 , axis =1)

# %%
Medicare_IN
# Out:
#                                                     Average Covered Charges_std  \
# DRG Definition
# 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC                           15941.252060
# 057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O...                 14085.285662
# 064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...                 29593.224554
# 065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...                 16732.402730
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...                 12606.452651
# ...                                                                         ...
# 885 - PSYCHOSES                                                    14305.274994
# 897 - ALCOHOL/DRUG ABUSE OR DEPENDENCE W/O REHA...                 11150.914646
# 917 - POISONING & TOXIC EFFECTS OF DRUGS W MCC                     24737.866985
# 918 - POISONING & TOXIC EFFECTS OF DRUGS W/O MCC                    9606.776451
# 948 - SIGNS & SYMPTOMS W/O MCC                                      9796.430291
#
#                                                     Average Covered Charges_avg
# DRG Definition
# 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC                           30481.989332
# 057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O...                 24307.762697
# 064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...                 48552.613451
# 065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...                 29492.125031
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...                 23592.928898
# ...                                                                         ...
# 885 - PSYCHOSES                                                    19929.455817
# 897 - ALCOHOL/DRUG ABUSE OR DEPENDENCE W/O REHA...                 17589.098728
# 917 - POISONING & TOXIC EFFECTS OF DRUGS W MCC                     40345.535785
# 918 - POISONING & TOXIC EFFECTS OF DRUGS W/O MCC                   17138.349268
# 948 - SIGNS & SYMPTOMS W/O MCC                                     18412.365572
#
# [100 rows x 2 columns]

# %%
#Coefficient of Variance, the standard deviation divided by the mean
Medicare_IN['Variation'] = Medicare_IN.apply(lambda x: x['Average Covered Charges_std']/x['Average Covered Charges_avg'],axis =1)

# %%
Medicare_IN
# Out:
#                                                     Average Covered Charges_std  \
# DRG Definition
# 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC                           15941.252060
# 057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O...                 14085.285662
# 064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...                 29593.224554
# 065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...                 16732.402730
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...                 12606.452651
# ...                                                                         ...
# 885 - PSYCHOSES                                                    14305.274994
# 897 - ALCOHOL/DRUG ABUSE OR DEPENDENCE W/O REHA...                 11150.914646
# 917 - POISONING & TOXIC EFFECTS OF DRUGS W MCC                     24737.866985
# 918 - POISONING & TOXIC EFFECTS OF DRUGS W/O MCC                    9606.776451
# 948 - SIGNS & SYMPTOMS W/O MCC                                      9796.430291
#
#                                                     Average Covered Charges_avg  \
# DRG Definition
# 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC                           30481.989332
# 057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O...                 24307.762697
# 064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...                 48552.613451
# 065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...                 29492.125031
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...                 23592.928898
# ...                                                                         ...
# 885 - PSYCHOSES                                                    19929.455817
# 897 - ALCOHOL/DRUG ABUSE OR DEPENDENCE W/O REHA...                 17589.098728
# 917 - POISONING & TOXIC EFFECTS OF DRUGS W MCC                     40345.535785
# 918 - POISONING & TOXIC EFFECTS OF DRUGS W/O MCC                   17138.349268
# 948 - SIGNS & SYMPTOMS W/O MCC                                     18412.365572
#
#                                                     Variation
# DRG Definition
# 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC             0.522973
# 057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O...   0.579456
# 064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...   0.609508
# 065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...   0.567352
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...   0.534332
# ...                                                       ...
# 885 - PSYCHOSES                                      0.717796
# 897 - ALCOHOL/DRUG ABUSE OR DEPENDENCE W/O REHA...   0.633967
# 917 - POISONING & TOXIC EFFECTS OF DRUGS W MCC       0.613150
# 918 - POISONING & TOXIC EFFECTS OF DRUGS W/O MCC     0.560543
# 948 - SIGNS & SYMPTOMS W/O MCC                       0.532057
#
# [100 rows x 3 columns]

# %%
Medicare_IN['Variation'].nlargest(3)
# Out:
# DRG Definition
# 885 - PSYCHOSES                                                              0.717796
# 897 - ALCOHOL/DRUG ABUSE OR DEPENDENCE W/O REHABILITATION THERAPY W/O MCC    0.633967
# 917 - POISONING & TOXIC EFFECTS OF DRUGS W MCC                               0.613150
# Name: Variation, dtype: float64

# %%
# Finding Standard deviation and mean for OutpatientAPC
Medicare_OUT = pd.concat(
[Medicare_Provider_Charge_Out[["APC","Average  Estimated Submitted Charges"]].groupby(['APC']).agg('std').add_suffix('_std'),
Medicare_Provider_Charge_Out[["APC","Average  Estimated Submitted Charges"]].groupby(['APC']).agg('mean').add_suffix('_avg')],
axis =1)

# %%
Medicare_OUT
# Out:
#                                                     Average  Estimated Submitted Charges_std  \
# APC
# 0012 - Level I Debridement & Destruction                                           95.646537
# 0013 - Level II Debridement & Destruction                                         255.987420
# 0015 - Level III Debridement & Destruction                                        240.708776
# 0019 - Level I Excision/ Biopsy                                                  2785.011224
# 0020 - Level II Excision/ Biopsy                                                 2524.137505
# 0073 - Level III Endoscopy Upper Airway                                           386.916025
# 0074 - Level IV Endoscopy Upper Airway                                           4271.015123
# 0078 - Level III Pulmonary Treatment                                              502.174061
# 0096 - Level II Noninvasive Physiologic Studies                                   476.260986
# 0203 - Level IV Nerve Injections                                                 2270.738462
# 0204 - Level I Nerve Injections                                                  1085.840468
# 0206 - Level II Nerve Injections                                                  926.809778
# 0207 - Level III Nerve Injections                                                1831.495687
# 0209 - Level II Extended EEG, Sleep, and Cardio...                               1534.402919
# 0265 - Level I Diagnostic and Screening Ultrasound                                263.006310
# 0267 - Level III Diagnostic and Screening Ultra...                                570.728415
# 0269 - Level II Echocardiogram Without Contrast                                  1071.004216
# 0270 - Level III Echocardiogram Without Contrast                                 1667.400506
# 0336 - Magnetic Resonance Imaging and Magnetic ...                               1041.538138
# 0368 - Level II Pulmonary Tests                                                   210.805996
# 0369 - Level III Pulmonary Tests                                                  706.835482
# 0377 - Level II Cardiac Imaging                                                  2153.294884
# 0604 - Level 1 Hospital Clinic Visits                                             235.176544
# 0605 - Level 2 Hospital Clinic Visits                                             116.187165
# 0606 - Level 3 Hospital Clinic Visits                                             158.991595
# 0607 - Level 4 Hospital Clinic Visits                                             183.848854
# 0608 - Level 5 Hospital Clinic Visits                                             329.155825
# 0690 - Level I Electronic Analysis of Devices                                     162.655018
# 0692 - Level II Electronic Analysis of Devices                                    795.774420
# 0698 - Level II Eye Tests & Treatments                                            328.498347
#
#                                                     Average  Estimated Submitted Charges_avg
# APC
# 0012 - Level I Debridement & Destruction                                           91.084383
# 0013 - Level II Debridement & Destruction                                         262.557685
# 0015 - Level III Debridement & Destruction                                        362.121980
# 0019 - Level I Excision/ Biopsy                                                  2264.425957
# 0020 - Level II Excision/ Biopsy                                                 3430.854940
# 0073 - Level III Endoscopy Upper Airway                                           856.563810
# 0074 - Level IV Endoscopy Upper Airway                                           7139.881202
# 0078 - Level III Pulmonary Treatment                                              593.795828
# 0096 - Level II Noninvasive Physiologic Studies                                   751.349472
# 0203 - Level IV Nerve Injections                                                 3675.637524
# 0204 - Level I Nerve Injections                                                  1279.784852
# 0206 - Level II Nerve Injections                                                 1342.679608
# 0207 - Level III Nerve Injections                                                2577.322607
# 0209 - Level II Extended EEG, Sleep, and Cardio...                               3631.534992
# 0265 - Level I Diagnostic and Screening Ultrasound                                487.034850
# 0267 - Level III Diagnostic and Screening Ultra...                               1057.552829
# 0269 - Level II Echocardiogram Without Contrast                                  1970.555344
# 0270 - Level III Echocardiogram Without Contrast                                 3033.884723
# 0336 - Magnetic Resonance Imaging and Magnetic ...                               2611.011616
# 0368 - Level II Pulmonary Tests                                                   316.265000
# 0369 - Level III Pulmonary Tests                                                 1016.850289
# 0377 - Level II Cardiac Imaging                                                  4574.468410
# 0604 - Level 1 Hospital Clinic Visits                                             169.784228
# 0605 - Level 2 Hospital Clinic Visits                                             202.371572
# 0606 - Level 3 Hospital Clinic Visits                                             278.383446
# 0607 - Level 4 Hospital Clinic Visits                                             351.449114
# 0608 - Level 5 Hospital Clinic Visits                                             453.843729
# 0690 - Level I Electronic Analysis of Devices                                     182.676141
# 0692 - Level II Electronic Analysis of Devices                                    705.369695
# 0698 - Level II Eye Tests & Treatments                                            250.677099

# %%
#Coefficient of Variance, the standard deviation divided by the mean
Medicare_OUT['Variation'] = Medicare_OUT.apply(lambda x: x['Average  Estimated Submitted Charges_std']/x['Average  Estimated Submitted Charges_avg'],axis =1)

# %%
Medicare_OUT
# Out:
#                                                     Average  Estimated Submitted Charges_std  \
# APC
# 0012 - Level I Debridement & Destruction                                           95.646537
# 0013 - Level II Debridement & Destruction                                         255.987420
# 0015 - Level III Debridement & Destruction                                        240.708776
# 0019 - Level I Excision/ Biopsy                                                  2785.011224
# 0020 - Level II Excision/ Biopsy                                                 2524.137505
# 0073 - Level III Endoscopy Upper Airway                                           386.916025
# 0074 - Level IV Endoscopy Upper Airway                                           4271.015123
# 0078 - Level III Pulmonary Treatment                                              502.174061
# 0096 - Level II Noninvasive Physiologic Studies                                   476.260986
# 0203 - Level IV Nerve Injections                                                 2270.738462
# 0204 - Level I Nerve Injections                                                  1085.840468
# 0206 - Level II Nerve Injections                                                  926.809778
# 0207 - Level III Nerve Injections                                                1831.495687
# 0209 - Level II Extended EEG, Sleep, and Cardio...                               1534.402919
# 0265 - Level I Diagnostic and Screening Ultrasound                                263.006310
# 0267 - Level III Diagnostic and Screening Ultra...                                570.728415
# 0269 - Level II Echocardiogram Without Contrast                                  1071.004216
# 0270 - Level III Echocardiogram Without Contrast                                 1667.400506
# 0336 - Magnetic Resonance Imaging and Magnetic ...                               1041.538138
# 0368 - Level II Pulmonary Tests                                                   210.805996
# 0369 - Level III Pulmonary Tests                                                  706.835482
# 0377 - Level II Cardiac Imaging                                                  2153.294884
# 0604 - Level 1 Hospital Clinic Visits                                             235.176544
# 0605 - Level 2 Hospital Clinic Visits                                             116.187165
# 0606 - Level 3 Hospital Clinic Visits                                             158.991595
# 0607 - Level 4 Hospital Clinic Visits                                             183.848854
# 0608 - Level 5 Hospital Clinic Visits                                             329.155825
# 0690 - Level I Electronic Analysis of Devices                                     162.655018
# 0692 - Level II Electronic Analysis of Devices                                    795.774420
# 0698 - Level II Eye Tests & Treatments                                            328.498347
#
#                                                     Average  Estimated Submitted Charges_avg  \
# APC
# 0012 - Level I Debridement & Destruction                                           91.084383
# 0013 - Level II Debridement & Destruction                                         262.557685
# 0015 - Level III Debridement & Destruction                                        362.121980
# 0019 - Level I Excision/ Biopsy                                                  2264.425957
# 0020 - Level II Excision/ Biopsy                                                 3430.854940
# 0073 - Level III Endoscopy Upper Airway                                           856.563810
# 0074 - Level IV Endoscopy Upper Airway                                           7139.881202
# 0078 - Level III Pulmonary Treatment                                              593.795828
# 0096 - Level II Noninvasive Physiologic Studies                                   751.349472
# 0203 - Level IV Nerve Injections                                                 3675.637524
# 0204 - Level I Nerve Injections                                                  1279.784852
# 0206 - Level II Nerve Injections                                                 1342.679608
# 0207 - Level III Nerve Injections                                                2577.322607
# 0209 - Level II Extended EEG, Sleep, and Cardio...                               3631.534992
# 0265 - Level I Diagnostic and Screening Ultrasound                                487.034850
# 0267 - Level III Diagnostic and Screening Ultra...                               1057.552829
# 0269 - Level II Echocardiogram Without Contrast                                  1970.555344
# 0270 - Level III Echocardiogram Without Contrast                                 3033.884723
# 0336 - Magnetic Resonance Imaging and Magnetic ...                               2611.011616
# 0368 - Level II Pulmonary Tests                                                   316.265000
# 0369 - Level III Pulmonary Tests                                                 1016.850289
# 0377 - Level II Cardiac Imaging                                                  4574.468410
# 0604 - Level 1 Hospital Clinic Visits                                             169.784228
# 0605 - Level 2 Hospital Clinic Visits                                             202.371572
# 0606 - Level 3 Hospital Clinic Visits                                             278.383446
# 0607 - Level 4 Hospital Clinic Visits                                             351.449114
# 0608 - Level 5 Hospital Clinic Visits                                             453.843729
# 0690 - Level I Electronic Analysis of Devices                                     182.676141
# 0692 - Level II Electronic Analysis of Devices                                    705.369695
# 0698 - Level II Eye Tests & Treatments                                            250.677099
#
#                                                     Variation
# APC
# 0012 - Level I Debridement & Destruction             1.050087
# 0013 - Level II Debridement & Destruction            0.974976
# 0015 - Level III Debridement & Destruction           0.664717
# 0019 - Level I Excision/ Biopsy                      1.229897
# 0020 - Level II Excision/ Biopsy                     0.735717
# 0073 - Level III Endoscopy Upper Airway              0.451707
# 0074 - Level IV Endoscopy Upper Airway               0.598191
# 0078 - Level III Pulmonary Treatment                 0.845702
# 0096 - Level II Noninvasive Physiologic Studies      0.633874
# 0203 - Level IV Nerve Injections                     0.617781
# 0204 - Level I Nerve Injections                      0.848455
# 0206 - Level II Nerve Injections                     0.690269
# 0207 - Level III Nerve Injections                    0.710619
# 0209 - Level II Extended EEG, Sleep, and Cardio...   0.422522
# 0265 - Level I Diagnostic and Screening Ultrasound   0.540015
# 0267 - Level III Diagnostic and Screening Ultra...   0.539669
# 0269 - Level II Echocardiogram Without Contrast      0.543504
# 0270 - Level III Echocardiogram Without Contrast     0.549593
# 0336 - Magnetic Resonance Imaging and Magnetic ...   0.398902
# 0368 - Level II Pulmonary Tests                      0.666549
# 0369 - Level III Pulmonary Tests                     0.695122
# 0377 - Level II Cardiac Imaging                      0.470720
# 0604 - Level 1 Hospital Clinic Visits                1.385150
# 0605 - Level 2 Hospital Clinic Visits                0.574128
# 0606 - Level 3 Hospital Clinic Visits                0.571124
# 0607 - Level 4 Hospital Clinic Visits                0.523117
# 0608 - Level 5 Hospital Clinic Visits                0.725262
# 0690 - Level I Electronic Analysis of Devices        0.890401
# 0692 - Level II Electronic Analysis of Devices       1.128166
# 0698 - Level II Eye Tests & Treatments               1.310444

# %%
Medicare_OUT['Variation'].nlargest(3)
# Out:
# APC
# 0604 - Level 1 Hospital Clinic Visits     1.385150
# 0698 - Level II Eye Tests & Treatments    1.310444
# 0019 - Level I Excision/ Biopsy           1.229897
# Name: Variation, dtype: float64

# %% [markdown]
# ### Part1B - Highest Cost Claims by provider
#  The cost claims of InPatientsDRG visbibly overtakes the cost claims of OutpatientsAPC.
#
#  The 3 Highest cost claims can be seen for follwing Providers-
#
# - BAYONNE HOSPITAL CENTER       - NJ - Newark
# - CROZER CHESTER MEDICAL CENTER - PA - Philadelphia
# - STANFORD HOSPITAL             - CA - San Mateo County

# %% [markdown]
# #### FOR InpatientDRG

# %%
Medicare_Provider_Charge_In.columns
# Out:
# Index(['DRG Definition', 'Provider Id', 'Provider Name',
#        'Provider Street Address', 'Provider City', 'Provider State',
#        'Provider Zip Code', 'Hospital Referral Region (HRR) Description',
#        'Total Discharges', 'Average Covered Charges', 'Average Total Payments',
#        'Average Medicare Payments'],
#       dtype='object')

# %%
#Finding the max of Average Covered Charges for InpatientDRG
Medicare_IN2 = Medicare_Provider_Charge_In.groupby(by=["DRG Definition"])[["Average Covered Charges"]].max().add_suffix('_max')
Medicare_IN2
# Out:
#                                                     Average Covered Charges_max
# DRG Definition
# 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC                           146892.00000
# 057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/O...                 148128.43750
# 064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...                 234912.70000
# 065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...                 162922.50000
# 066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFAR...                 117831.14290
# ...                                                                         ...
# 885 - PSYCHOSES                                                    144522.66670
# 897 - ALCOHOL/DRUG ABUSE OR DEPENDENCE W/O REHA...                  79932.53846
# 917 - POISONING & TOXIC EFFECTS OF DRUGS W MCC                     236455.90910
# 918 - POISONING & TOXIC EFFECTS OF DRUGS W/O MCC                    79965.72000
# 948 - SIGNS & SYMPTOMS W/O MCC                                      84846.50000
#
# [100 rows x 1 columns]

# %%
Medicare_IN2 = Medicare_IN2.reset_index()

# %%
#Merging the max value with InpatientDRG dataset
Medicare_IN_MERGE = Medicare_Provider_Charge_In.merge(Medicare_IN2,on='DRG Definition', how='left')
Medicare_IN_MERGE.head()
# Out:
#                              DRG Definition  Provider Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
#
#                       Provider Name     Provider Street Address Provider City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider State  Provider Zip Code  \
# 0             AL              36301
# 1             AL              35957
# 2             AL              35631
# 3             AL              35235
# 4             AL              35007
#
#   Hospital Referral Region (HRR) Description  Total Discharges  \
# 0                                AL - Dothan                91
# 1                            AL - Birmingham                14
# 2                            AL - Birmingham                24
# 3                            AL - Birmingham                25
# 4                            AL - Birmingham                18
#
#    Average Covered Charges  Average Total Payments  Average Medicare Payments  \
# 0              32963.07692             5777.241758                4763.736264
# 1              15131.85714             5787.571429                4976.714286
# 2              37560.37500             5434.958333                4453.791667
# 3              13998.28000             5417.560000                4129.160000
# 4              31633.27778             5658.333333                4851.444444
#
#    Average Covered Charges_max
# 0                     146892.0
# 1                     146892.0
# 2                     146892.0
# 3                     146892.0
# 4                     146892.0

# %%
#function to get the max indicator
def difftyp(Medicare_IN_MERGE):
    if ((Medicare_IN_MERGE['Average Covered Charges_max']  == Medicare_IN_MERGE['Average Covered Charges'])):
        return 1
    else:
        return 0

# %%
Medicare_IN_MERGE['MAX'] = Medicare_IN_MERGE.apply(difftyp, axis=1)
Medicare_IN_MERGE
# Out:
#                                   DRG Definition  Provider Id  \
# 0       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4       039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
# ...                                          ...          ...
# 163060            948 - SIGNS & SYMPTOMS W/O MCC       670041
# 163061            948 - SIGNS & SYMPTOMS W/O MCC       670055
# 163062            948 - SIGNS & SYMPTOMS W/O MCC       670056
# 163063            948 - SIGNS & SYMPTOMS W/O MCC       670060
# 163064            948 - SIGNS & SYMPTOMS W/O MCC       670068
#
#                                           Provider Name  \
# 0                      SOUTHEAST ALABAMA MEDICAL CENTER
# 1                         MARSHALL MEDICAL CENTER SOUTH
# 2                        ELIZA COFFEE MEMORIAL HOSPITAL
# 3                                     ST VINCENT'S EAST
# 4                         SHELBY BAPTIST MEDICAL CENTER
# ...                                                 ...
# 163060                  SETON MEDICAL CENTER WILLIAMSON
# 163061                     METHODIST STONE OAK HOSPITAL
# 163062                        SETON MEDICAL CENTER HAYS
# 163063       TEXAS REGIONAL MEDICAL CENTER AT SUNNYVALE
# 163064  TEXAS HEALTH PRESBYTERIAN HOSPITAL FLOWER MOUND
#
#            Provider Street Address Provider City Provider State  \
# 0           1108 ROSS CLARK CIRCLE        DOTHAN             AL
# 1       2505 U S HIGHWAY 431 NORTH          BOAZ             AL
# 2               205 MARENGO STREET      FLORENCE             AL
# 3       50 MEDICAL PARK EAST DRIVE    BIRMINGHAM             AL
# 4          1000 FIRST STREET NORTH     ALABASTER             AL
# ...                            ...           ...            ...
# 163060           201 SETON PARKWAY    ROUND ROCK             TX
# 163061        1139 E SONTERRA BLVD   SAN ANTONIO             TX
# 163062              6001 KYLE PKWY          KYLE             TX
# 163063      231 SOUTH COLLINS ROAD     SUNNYVALE             TX
# 163064      4400 LONG PRAIRIE ROAD  FLOWER MOUND             TX
#
#         Provider Zip Code Hospital Referral Region (HRR) Description  \
# 0                   36301                                AL - Dothan
# 1                   35957                            AL - Birmingham
# 2                   35631                            AL - Birmingham
# 3                   35235                            AL - Birmingham
# 4                   35007                            AL - Birmingham
# ...                   ...                                        ...
# 163060              78664                                TX - Austin
# 163061              78258                           TX - San Antonio
# 163062              78640                                TX - Austin
# 163063              75182                                TX - Dallas
# 163064              75028                                TX - Dallas
#
#         Total Discharges  Average Covered Charges  Average Total Payments  \
# 0                     91              32963.07692             5777.241758
# 1                     14              15131.85714             5787.571429
# 2                     24              37560.37500             5434.958333
# 3                     25              13998.28000             5417.560000
# 4                     18              31633.27778             5658.333333
# ...                  ...                      ...                     ...
# 163060                23              26314.39130             3806.869565
# 163061                11              21704.72727             4027.363636
# 163062                19              39121.73684             5704.368421
# 163063                11              28873.09091             7663.090909
# 163064                12              15042.00000             3539.750000
#
#         Average Medicare Payments  Average Covered Charges_max  MAX
# 0                     4763.736264                     146892.0    0
# 1                     4976.714286                     146892.0    0
# 2                     4453.791667                     146892.0    0
# 3                     4129.160000                     146892.0    0
# 4                     4851.444444                     146892.0    0
# ...                           ...                          ...  ...
# 163060                3071.391304                      84846.5    0
# 163061                2649.727273                      84846.5    0
# 163062                4058.368421                      84846.5    0
# 163063                6848.545455                      84846.5    0
# 163064                2887.416667                      84846.5    0
#
# [163065 rows x 14 columns]

# %%
#getting number of times a provider has charge max value for procedure
Medicare_IN_MAXCALC_PROVIDER= Medicare_IN_MERGE.groupby(by=['Provider Name','Hospital Referral Region (HRR) Description'])[['MAX']].sum().add_suffix('_sum')
Medicare_IN_MAXCALC_PROVIDER
# Out:
#                                                                                        MAX_sum
# Provider Name                              Hospital Referral Region (HRR) Description
# ABBEVILLE GENERAL HOSPITAL                 LA - Lafayette                                    0
# ABBOTT NORTHWESTERN HOSPITAL               MN - Minneapolis                                  0
# ABILENE REGIONAL MEDICAL CENTER            TX - Abilene                                      0
# ABINGTON MEMORIAL HOSPITAL                 PA - Philadelphia                                 0
# ACMH HOSPITAL                              PA - Pittsburgh                                   0
# ...                                                                                        ...
# YORK HOSPITAL                              ME - Portland                                     0
#                                            PA - York                                         0
# YUKON KUSKOKWIM DELTA REG HOSPITAL         AK - Anchorage                                    0
# YUMA REGIONAL MEDICAL CENTER               AZ - Phoenix                                      0
# ZUNI COMPREHENSIVE COMMUNITY HEALTH CENTER NM - Albuquerque                                  0
#
# [3335 rows x 1 columns]

# %%
Medicare_IN_MAXCALC_PROVIDER['MAX_sum'].nlargest(3)
# Out:
# Provider Name                  Hospital Referral Region (HRR) Description
# BAYONNE HOSPITAL CENTER        NJ - Newark                                   23
# CROZER CHESTER MEDICAL CENTER  PA - Philadelphia                             11
# STANFORD HOSPITAL              CA - San Mateo County                         10
# Name: MAX_sum, dtype: int64

# %% [markdown]
# #### FOR OutpatientAPC

# %%
Medicare_Provider_Charge_Out.columns
# Out:
# Index(['APC', 'Provider Id', 'Provider Name', 'Provider Street Address',
#        'Provider City', 'Provider State', 'Provider Zip Code',
#        'Hospital Referral Region (HRR) Description', 'Outpatient Services',
#        'Average  Estimated Submitted Charges', 'Average Total Payments'],
#       dtype='object')

# %%
#Finding the max Average Estimated Submitted Charges for Outpatient APCs
Medicare_OUT2 = Medicare_Provider_Charge_Out.groupby(by=["APC"])[["Average  Estimated Submitted Charges"]].max().add_suffix('_max')
Medicare_OUT2
# Out:
#                                                     Average  Estimated Submitted Charges_max
# APC
# 0012 - Level I Debridement & Destruction                                          841.900000
# 0013 - Level II Debridement & Destruction                                        5231.000000
# 0015 - Level III Debridement & Destruction                                       3080.849630
# 0019 - Level I Excision/ Biopsy                                                 26466.645000
# 0020 - Level II Excision/ Biopsy                                                19018.408820
# 0073 - Level III Endoscopy Upper Airway                                          2771.000000
# 0074 - Level IV Endoscopy Upper Airway                                          32105.636360
# 0078 - Level III Pulmonary Treatment                                             7098.950000
# 0096 - Level II Noninvasive Physiologic Studies                                  5362.704231
# 0203 - Level IV Nerve Injections                                                15461.359230
# 0204 - Level I Nerve Injections                                                 10079.668180
# 0206 - Level II Nerve Injections                                                 8646.919412
# 0207 - Level III Nerve Injections                                               17183.764380
# 0209 - Level II Extended EEG, Sleep, and Cardio...                              16080.900000
# 0265 - Level I Diagnostic and Screening Ultrasound                               3036.704918
# 0267 - Level III Diagnostic and Screening Ultra...                               7566.223986
# 0269 - Level II Echocardiogram Without Contrast                                 11451.318580
# 0270 - Level III Echocardiogram Without Contrast                                13984.785880
# 0336 - Magnetic Resonance Imaging and Magnetic ...                              13259.000000
# 0368 - Level II Pulmonary Tests                                                  2585.596429
# 0369 - Level III Pulmonary Tests                                                 7261.000000
# 0377 - Level II Cardiac Imaging                                                 18681.970060
# 0604 - Level 1 Hospital Clinic Visits                                            9780.157143
# 0605 - Level 2 Hospital Clinic Visits                                            1215.241070
# 0606 - Level 3 Hospital Clinic Visits                                            1473.559603
# 0607 - Level 4 Hospital Clinic Visits                                            1999.582500
# 0608 - Level 5 Hospital Clinic Visits                                            3666.534545
# 0690 - Level I Electronic Analysis of Devices                                    1633.000000
# 0692 - Level II Electronic Analysis of Devices                                   9105.980000
# 0698 - Level II Eye Tests & Treatments                                           4187.255000

# %%
Medicare_OUT2 = Medicare_OUT2.reset_index()

# %%
#Merging the max value with InpatientDRG dataset
Medicare_OUT_MERGE = Medicare_Provider_Charge_Out.merge(Medicare_OUT2,on='APC', how='left')
Medicare_OUT_MERGE
# Out:
#                                             APC  Provider Id  \
# 0      0012 - Level I Debridement & Destruction        10029
# 1      0012 - Level I Debridement & Destruction        20024
# 2      0012 - Level I Debridement & Destruction        30064
# 3      0012 - Level I Debridement & Destruction        30088
# 4      0012 - Level I Debridement & Destruction        30111
# ...                                         ...          ...
# 43367    0698 - Level II Eye Tests & Treatments       520098
# 43368    0698 - Level II Eye Tests & Treatments       520100
# 43369    0698 - Level II Eye Tests & Treatments       520116
# 43370    0698 - Level II Eye Tests & Treatments       520177
# 43371    0698 - Level II Eye Tests & Treatments       670034
#
#                                            Provider Name  \
# 0                    EAST ALABAMA MEDICAL CENTER AND SNF
# 1                     CENTRAL PENINSULA GENERAL HOSPITAL
# 2       UNIVERSITY OF ARIZONA MEDICAL CTR-UNIVERSIT, THE
# 3                          BANNER BAYWOOD MEDICAL CENTER
# 4      UNIVERSITY OF ARIZONA MEDICAL CTR- SOUTH CAM, THE
# ...                                                  ...
# 43367    UNIVERSITY OF WI  HOSPITALS & CLINICS AUTHORITY
# 43368                                   BELOIT MEM HSPTL
# 43369  UW HLTH PARTNERS - WATERTOWN REGIONAL MEDICAL CTR
# 43370                       FROEDTERT MEM LUTHERAN HSPTL
# 43371                  SCOTT & WHITE HOSPITAL-ROUND ROCK
#
#           Provider Street Address Provider City Provider State  \
# 0          2000 PEPPERELL PARKWAY       OPELIKA             AL
# 1              250 HOSPITAL PLACE      SOLDOTNA             AK
# 2      1501 NORTH CAMPBELL AVENUE        TUCSON             AZ
# 3        6644 EAST BAYWOOD AVENUE          MESA             AZ
# 4               2800 EAST AJO WAY        TUCSON             AZ
# ...                           ...           ...            ...
# 43367         600 HIGHLAND AVENUE       MADISON             WI
# 43368              1969 W HART RD        BELOIT             WI
# 43369             125 HOSPITAL DR     WATERTOWN             WI
# 43370        9200 W WISCONSIN AVE     MILWAUKEE             WI
# 43371         300 UNIVERSITY BLVD    ROUND ROCK             TX
#
#        Provider Zip Code Hospital Referral Region (HRR) Description  \
# 0                  36801                            AL - Birmingham
# 1                  99669                             AK - Anchorage
# 2                  85724                                AZ - Tucson
# 3                  85206                                  AZ - Mesa
# 4                  85713                                AZ - Tucson
# ...                  ...                                        ...
# 43367              53792                               WI - Madison
# 43368              53511                               WI - Madison
# 43369              53098                               WI - Madison
# 43370              53226                             WI - Milwaukee
# 43371              78664                                TX - Austin
#
#        Outpatient Services  Average  Estimated Submitted Charges  \
# 0                       23                             78.086957
# 1                      994                            149.589749
# 2                     1765                             50.135411
# 3                       20                            112.400000
# 4                       22                            152.045455
# ...                    ...                                   ...
# 43367                 2852                            211.752854
# 43368                  912                            164.068882
# 43369                  188                            119.579787
# 43370                 1554                            155.406969
# 43371                 1141                            352.334356
#
#        Average Total Payments  Average  Estimated Submitted Charges_max
# 0                   21.910435                                   841.900
# 1                   36.623853                                   841.900
# 2                   14.541841                                   841.900
# 3                   23.736000                                   841.900
# 4                   16.569091                                   841.900
# ...                       ...                                       ...
# 43367               71.776392                                  4187.255
# 43368               65.369989                                  4187.255
# 43369               67.520000                                  4187.255
# 43370               66.719949                                  4187.255
# 43371               64.012349                                  4187.255
#
# [43372 rows x 12 columns]

# %%
#function to get the max indicator
def difftyp(Medicare_OUT_MERGE):
    if ((Medicare_OUT_MERGE['Average  Estimated Submitted Charges_max']  == Medicare_OUT_MERGE['Average  Estimated Submitted Charges'])):
        return 1
    else:
        return 0

# %%
Medicare_OUT_MERGE['MAX'] = Medicare_OUT_MERGE.apply(difftyp, axis=1)
Medicare_OUT_MERGE
# Out:
#                                             APC  Provider Id  \
# 0      0012 - Level I Debridement & Destruction        10029
# 1      0012 - Level I Debridement & Destruction        20024
# 2      0012 - Level I Debridement & Destruction        30064
# 3      0012 - Level I Debridement & Destruction        30088
# 4      0012 - Level I Debridement & Destruction        30111
# ...                                         ...          ...
# 43367    0698 - Level II Eye Tests & Treatments       520098
# 43368    0698 - Level II Eye Tests & Treatments       520100
# 43369    0698 - Level II Eye Tests & Treatments       520116
# 43370    0698 - Level II Eye Tests & Treatments       520177
# 43371    0698 - Level II Eye Tests & Treatments       670034
#
#                                            Provider Name  \
# 0                    EAST ALABAMA MEDICAL CENTER AND SNF
# 1                     CENTRAL PENINSULA GENERAL HOSPITAL
# 2       UNIVERSITY OF ARIZONA MEDICAL CTR-UNIVERSIT, THE
# 3                          BANNER BAYWOOD MEDICAL CENTER
# 4      UNIVERSITY OF ARIZONA MEDICAL CTR- SOUTH CAM, THE
# ...                                                  ...
# 43367    UNIVERSITY OF WI  HOSPITALS & CLINICS AUTHORITY
# 43368                                   BELOIT MEM HSPTL
# 43369  UW HLTH PARTNERS - WATERTOWN REGIONAL MEDICAL CTR
# 43370                       FROEDTERT MEM LUTHERAN HSPTL
# 43371                  SCOTT & WHITE HOSPITAL-ROUND ROCK
#
#           Provider Street Address Provider City Provider State  \
# 0          2000 PEPPERELL PARKWAY       OPELIKA             AL
# 1              250 HOSPITAL PLACE      SOLDOTNA             AK
# 2      1501 NORTH CAMPBELL AVENUE        TUCSON             AZ
# 3        6644 EAST BAYWOOD AVENUE          MESA             AZ
# 4               2800 EAST AJO WAY        TUCSON             AZ
# ...                           ...           ...            ...
# 43367         600 HIGHLAND AVENUE       MADISON             WI
# 43368              1969 W HART RD        BELOIT             WI
# 43369             125 HOSPITAL DR     WATERTOWN             WI
# 43370        9200 W WISCONSIN AVE     MILWAUKEE             WI
# 43371         300 UNIVERSITY BLVD    ROUND ROCK             TX
#
#        Provider Zip Code Hospital Referral Region (HRR) Description  \
# 0                  36801                            AL - Birmingham
# 1                  99669                             AK - Anchorage
# 2                  85724                                AZ - Tucson
# 3                  85206                                  AZ - Mesa
# 4                  85713                                AZ - Tucson
# ...                  ...                                        ...
# 43367              53792                               WI - Madison
# 43368              53511                               WI - Madison
# 43369              53098                               WI - Madison
# 43370              53226                             WI - Milwaukee
# 43371              78664                                TX - Austin
#
#        Outpatient Services  Average  Estimated Submitted Charges  \
# 0                       23                             78.086957
# 1                      994                            149.589749
# 2                     1765                             50.135411
# 3                       20                            112.400000
# 4                       22                            152.045455
# ...                    ...                                   ...
# 43367                 2852                            211.752854
# 43368                  912                            164.068882
# 43369                  188                            119.579787
# 43370                 1554                            155.406969
# 43371                 1141                            352.334356
#
#        Average Total Payments  Average  Estimated Submitted Charges_max  MAX
# 0                   21.910435                                   841.900    0
# 1                   36.623853                                   841.900    0
# 2                   14.541841                                   841.900    0
# 3                   23.736000                                   841.900    0
# 4                   16.569091                                   841.900    0
# ...                       ...                                       ...  ...
# 43367               71.776392                                  4187.255    0
# 43368               65.369989                                  4187.255    0
# 43369               67.520000                                  4187.255    0
# 43370               66.719949                                  4187.255    0
# 43371               64.012349                                  4187.255    0
#
# [43372 rows x 13 columns]

# %%
#getting number of times a provider has charge max value for procedure
Medicare_OUT_MAXCALC_PROVIDER= pd.DataFrame(Medicare_OUT_MERGE.groupby(by=['Provider Name','Hospital Referral Region (HRR) Description'])[['MAX']].sum().add_suffix('_sum'),)

# %%
Medicare_OUT_MAXCALC_PROVIDER
# Out:
#                                                                                  MAX_sum
# Provider Name                        Hospital Referral Region (HRR) Description
# ABBEVILLE GENERAL HOSPITAL           LA - Lafayette                                    0
# ABBOTT NORTHWESTERN HOSPITAL         MN - Minneapolis                                  0
# ABILENE REGIONAL MEDICAL CENTER      TX - Abilene                                      0
# ABINGTON MEMORIAL HOSPITAL           PA - Philadelphia                                 0
# ACMH HOSPITAL                        PA - Pittsburgh                                   0
# ...                                                                                  ...
# YAVAPAI REGIONAL MEDICAL CENTER      AZ - Phoenix                                      0
# YAVAPAI REGIONAL MEDICAL CENTER-EAST AZ - Phoenix                                      0
# YORK HOSPITAL                        ME - Portland                                     0
#                                      PA - York                                         0
# YUMA REGIONAL MEDICAL CENTER         AZ - Phoenix                                      0
#
# [3134 rows x 1 columns]

# %%
Medicare_OUT_MAXCALC_PROVIDER['MAX_sum'].nlargest(5)
# Out:
# Provider Name                             Hospital Referral Region (HRR) Description
# CAPITAL HEALTH MEDICAL CENTER - HOPEWELL  PA - Philadelphia                             2
# COLUMBIA HOSPITAL                         FL - Fort Lauderdale                          2
# FORT WALTON BEACH MEDICAL CENTER          FL - Pensacola                                2
# BEVERLY HOSPITAL CORPORATION              MA - Boston                                   1
# CENTINELA HOSPITAL MEDICAL CENTER         CA - Los Angeles                              1
# Name: MAX_sum, dtype: int64

# %% [markdown]
# ### Part1C - Highest Cost Claims by Region
# Combining the counts of Inpatient and Outpatients
#
# Following are the 3 Highest cost claims by Region -
#
# Hospital Referral Region (HRR) Description :
# - CA - Contra Costa County
# - CA - San Mateo County
# - CA - Santa Cruz

# %% [markdown]
# #### FOR InpatientDRG

# %%
#Finding the mean of Average Covered Charges for InpatientDRG by DRG Defination and Region
Medicare_IN_AGG = Medicare_Provider_Charge_In.groupby(by=['DRG Definition', 'Hospital Referral Region (HRR) Description'])[['Average Covered Charges']].mean().add_suffix('_avg')
Medicare_IN_AGG
# Out:
#                                                                                      Average Covered Charges_avg
# DRG Definition                           Hospital Referral Region (HRR) Description
# 039 - EXTRACRANIAL PROCEDURES W/O CC/MCC AK - Anchorage                                             34805.130430
#                                          AL - Birmingham                                            40237.361538
#                                          AL - Dothan                                                36285.182905
#                                          AL - Huntsville                                            18878.955554
#                                          AL - Mobile                                                22802.270118
# ...                                                                                                          ...
# 948 - SIGNS & SYMPTOMS W/O MCC           WI - Wausau                                                13291.380000
#                                          WV - Charleston                                            10526.475501
#                                          WV - Huntington                                            11329.841077
#                                          WV - Morgantown                                            10785.860828
#                                          WY - Casper                                                12021.421050
#
# [28961 rows x 1 columns]

# %%
Medicare_IN_AGG  = Medicare_IN_AGG.reset_index()

# %%
Medicare_IN_AGG.head()
# Out:
#                              DRG Definition  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
#
#   Hospital Referral Region (HRR) Description  Average Covered Charges_avg
# 0                             AK - Anchorage                 34805.130430
# 1                            AL - Birmingham                 40237.361538
# 2                                AL - Dothan                 36285.182905
# 3                            AL - Huntsville                 18878.955554
# 4                                AL - Mobile                 22802.270118

# %%
#Finding the max for InpatientDRG DRG Definition
Medicare_IN_MAX = Medicare_IN_AGG.groupby(by=['DRG Definition'])[['Average Covered Charges_avg']].max().add_suffix('_max')

# %%
Medicare_IN_MAX = Medicare_IN_MAX.reset_index()

# %%
Medicare_IN_MAX.head()
# Out:
#                                       DRG Definition  \
# 0           039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 1  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...
# 2  064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...
# 3  065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...
# 4  066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...
#
#    Average Covered Charges_avg_max
# 0                    105929.470600
# 1                    148128.437500
# 2                    145720.057518
# 3                     73820.938782
# 4                     65418.983067

# %%
#Merging The mean and max - will give side by side comparison of region having highest claims
Medicare_IN_MERGE = Medicare_IN_AGG.merge(Medicare_IN_MAX,on='DRG Definition', how='left')

# %%
Medicare_IN_MERGE.head()
# Out:
#                              DRG Definition  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
#
#   Hospital Referral Region (HRR) Description  Average Covered Charges_avg  \
# 0                             AK - Anchorage                 34805.130430
# 1                            AL - Birmingham                 40237.361538
# 2                                AL - Dothan                 36285.182905
# 3                            AL - Huntsville                 18878.955554
# 4                                AL - Mobile                 22802.270118
#
#    Average Covered Charges_avg_max
# 0                      105929.4706
# 1                      105929.4706
# 2                      105929.4706
# 3                      105929.4706
# 4                      105929.4706

# %%
#function to get the max indicator
def difftyp(Medicare_IN_MERGE):
    if ((Medicare_IN_MERGE['Average Covered Charges_avg'] == Medicare_IN_MERGE['Average Covered Charges_avg_max'])):
        return 1
    elif ((Medicare_IN_MERGE['Average Covered Charges_avg'] > Medicare_IN_MERGE['Average Covered Charges_avg_max'])):
        return 1
    else:
        return 0

# %%
Medicare_IN_MERGE['MAX'] = Medicare_IN_MERGE.apply(difftyp, axis=1)

# %%
Medicare_IN_MERGE[Medicare_IN_MERGE['MAX'] == 1].head()
# Out:
#                                          DRG Definition  \
# 22             039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 330   057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...
# 588   064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...
# 907   065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...
# 1198  066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...
#
#      Hospital Referral Region (HRR) Description  Average Covered Charges_avg  \
# 22                                    CA - Napa                105929.470600
# 330                       CA - San Mateo County                148128.437500
# 588                    CA - Contra Costa County                145720.057518
# 907                       CA - San Mateo County                 73820.938782
# 1198                   CA - Contra Costa County                 65418.983067
#
#       Average Covered Charges_avg_max  MAX
# 22                      105929.470600    1
# 330                     148128.437500    1
# 588                     145720.057518    1
# 907                      73820.938782    1
# 1198                     65418.983067    1

# %%
#getting number of times a region has charge max value for procedure
Medicare_IN_MERGE_GROUPED = Medicare_IN_MERGE.groupby(['Hospital Referral Region (HRR) Description'])[['MAX']].sum().add_suffix('_sum')

# %%
Medicare_IN_MERGE_GROUPED = Medicare_IN_MERGE_GROUPED.reset_index()

# %%
Medicare_IN_MERGE_GROUPED
# Out:
#     Hospital Referral Region (HRR) Description  MAX_sum
# 0                               AK - Anchorage        0
# 1                              AL - Birmingham        0
# 2                                  AL - Dothan        0
# 3                              AL - Huntsville        0
# 4                                  AL - Mobile        0
# ..                                         ...      ...
# 301                                WI - Wausau        0
# 302                            WV - Charleston        0
# 303                            WV - Huntington        0
# 304                            WV - Morgantown        0
# 305                                WY - Casper        0
#
# [306 rows x 2 columns]

# %% [markdown]
# #### FOR OutpatientAPC

# %%
Medicare_Provider_Charge_Out.columns
# Out:
# Index(['APC', 'Provider Id', 'Provider Name', 'Provider Street Address',
#        'Provider City', 'Provider State', 'Provider Zip Code',
#        'Hospital Referral Region (HRR) Description', 'Outpatient Services',
#        'Average  Estimated Submitted Charges', 'Average Total Payments'],
#       dtype='object')

# %%
#Finding the mean of Average Covered Charges for Outpatient by APC and Region
Medicare_Out_AGG = Medicare_Provider_Charge_Out.groupby(['APC', 'Hospital Referral Region (HRR) Description'])[['Average  Estimated Submitted Charges']].mean().add_suffix('_avg')

# %%
Medicare_Out_AGG = Medicare_Out_AGG.reset_index()

# %%
Medicare_Out_AGG.head()
# Out:
#                                         APC  \
# 0  0012 - Level I Debridement & Destruction
# 1  0012 - Level I Debridement & Destruction
# 2  0012 - Level I Debridement & Destruction
# 3  0012 - Level I Debridement & Destruction
# 4  0012 - Level I Debridement & Destruction
#
#   Hospital Referral Region (HRR) Description  \
# 0                             AK - Anchorage
# 1                            AL - Birmingham
# 2                            AR - Fort Smith
# 3                             AR - Jonesboro
# 4                           AR - Little Rock
#
#    Average  Estimated Submitted Charges_avg
# 0                                149.589749
# 1                                 78.086957
# 2                                 80.102439
# 3                                 16.993333
# 4                                 96.968863

# %%
#Finding the max for Outpatient
Medicare_Out_MAX = Medicare_Out_AGG.groupby(['APC'])[['Average  Estimated Submitted Charges_avg']].max().add_suffix('_max')

# %%
Medicare_Out_MAX = Medicare_Out_MAX.reset_index()

# %%
Medicare_Out_MAX.head()
# Out:
#                                           APC  \
# 0    0012 - Level I Debridement & Destruction
# 1   0013 - Level II Debridement & Destruction
# 2  0015 - Level III Debridement & Destruction
# 3             0019 - Level I Excision/ Biopsy
# 4            0020 - Level II Excision/ Biopsy
#
#    Average  Estimated Submitted Charges_avg_max
# 0                                    438.307045
# 1                                   1042.707451
# 2                                   1478.536545
# 3                                  15946.325655
# 4                                  15784.975000

# %%
#Merging The mean and max - will give side by side comparison of region having highest claims
Medicare_Out_MERGE = Medicare_Out_AGG.merge(Medicare_Out_MAX,on='APC', how='left')

# %%
Medicare_Out_MERGE
# Out:
#                                            APC  \
# 0     0012 - Level I Debridement & Destruction
# 1     0012 - Level I Debridement & Destruction
# 2     0012 - Level I Debridement & Destruction
# 3     0012 - Level I Debridement & Destruction
# 4     0012 - Level I Debridement & Destruction
# ...                                        ...
# 7505    0698 - Level II Eye Tests & Treatments
# 7506    0698 - Level II Eye Tests & Treatments
# 7507    0698 - Level II Eye Tests & Treatments
# 7508    0698 - Level II Eye Tests & Treatments
# 7509    0698 - Level II Eye Tests & Treatments
#
#      Hospital Referral Region (HRR) Description  \
# 0                                AK - Anchorage
# 1                               AL - Birmingham
# 2                               AR - Fort Smith
# 3                                AR - Jonesboro
# 4                              AR - Little Rock
# ...                                         ...
# 7505                               WI - Madison
# 7506                            WI - Marshfield
# 7507                             WI - Milwaukee
# 7508                                WI - Neenah
# 7509                            WV - Morgantown
#
#       Average  Estimated Submitted Charges_avg  \
# 0                                   149.589749
# 1                                    78.086957
# 2                                    80.102439
# 3                                    16.993333
# 4                                    96.968863
# ...                                        ...
# 7505                                160.084480
# 7506                                105.767698
# 7507                                155.406969
# 7508                                135.754386
# 7509                                131.897057
#
#       Average  Estimated Submitted Charges_avg_max
# 0                                       438.307045
# 1                                       438.307045
# 2                                       438.307045
# 3                                       438.307045
# 4                                       438.307045
# ...                                            ...
# 7505                                   1511.727113
# 7506                                   1511.727113
# 7507                                   1511.727113
# 7508                                   1511.727113
# 7509                                   1511.727113
#
# [7510 rows x 4 columns]

# %%
#function to get the max indicator
def difftyp(Medicare_Out_MERGE):
    if ((Medicare_Out_MERGE['Average  Estimated Submitted Charges_avg'] == Medicare_Out_MERGE['Average  Estimated Submitted Charges_avg_max'])):
        return 1
    elif ((Medicare_Out_MERGE['Average  Estimated Submitted Charges_avg'] > Medicare_Out_MERGE['Average  Estimated Submitted Charges_avg_max'])):
        return 1
    else:
        return 0

# %%
Medicare_Out_MERGE['MAX'] = Medicare_Out_MERGE.apply(difftyp, axis=1)

# %%
Medicare_Out_MERGE[Medicare_Out_MERGE['MAX'] == 1].head()
# Out:
#                                              APC  \
# 93      0012 - Level I Debridement & Destruction
# 160    0013 - Level II Debridement & Destruction
# 582   0015 - Level III Debridement & Destruction
# 756              0019 - Level I Excision/ Biopsy
# 1013            0020 - Level II Excision/ Biopsy
#
#      Hospital Referral Region (HRR) Description  \
# 93                                   NE - Omaha
# 160                                 AL - Dothan
# 582                               MI - Dearborn
# 756                            CA - Los Angeles
# 1013                                IL - Aurora
#
#       Average  Estimated Submitted Charges_avg  \
# 93                                  438.307045
# 160                                1042.707451
# 582                                1478.536545
# 756                               15946.325655
# 1013                              15784.975000
#
#       Average  Estimated Submitted Charges_avg_max  MAX
# 93                                      438.307045    1
# 160                                    1042.707451    1
# 582                                    1478.536545    1
# 756                                   15946.325655    1
# 1013                                  15784.975000    1

# %%
#getting number of times a region has charge max value for procedure
Medicare_Out_MERGE_GROUPED = Medicare_Out_MERGE.groupby(['Hospital Referral Region (HRR) Description'])[['MAX']].sum().add_suffix('_sum')

# %%
Medicare_Out_MERGE_GROUPED = Medicare_Out_MERGE_GROUPED.reset_index()

# %%
Medicare_Out_MERGE_GROUPED.head()
# Out:
#   Hospital Referral Region (HRR) Description  MAX_sum
# 0                             AK - Anchorage        0
# 1                            AL - Birmingham        0
# 2                                AL - Dothan        1
# 3                            AL - Huntsville        1
# 4                                AL - Mobile        0

# %%
Medicare_IN_MERGE_GROUPED.head()
# Out:
#   Hospital Referral Region (HRR) Description  MAX_sum
# 0                             AK - Anchorage        0
# 1                            AL - Birmingham        0
# 2                                AL - Dothan        0
# 3                            AL - Huntsville        0
# 4                                AL - Mobile        0

# %%
frames = [Medicare_IN_MERGE_GROUPED, Medicare_Out_MERGE_GROUPED]
Medicare_data_REGION = pd.concat(frames)

# %%
Medicare_data_REGION
# Out:
#     Hospital Referral Region (HRR) Description  MAX_sum
# 0                               AK - Anchorage        0
# 1                              AL - Birmingham        0
# 2                                  AL - Dothan        0
# 3                              AL - Huntsville        0
# 4                                  AL - Mobile        0
# ..                                         ...      ...
# 299                                WI - Wausau        0
# 300                            WV - Charleston        0
# 301                            WV - Huntington        0
# 302                            WV - Morgantown        0
# 303                                WY - Casper        0
#
# [610 rows x 2 columns]

# %%
#getting the total sum of occurance
Medicare_data_REGION_GROUPED = pd.DataFrame(Medicare_data_REGION[['Hospital Referral Region (HRR) Description','MAX_sum']].groupby(['Hospital Referral Region (HRR) Description']).agg('sum').add_suffix('_agg'),)

# %%
Medicare_data_REGION_GROUPED['MAX_sum_agg'].nlargest(3)
# Out:
# Hospital Referral Region (HRR) Description
# CA - Contra Costa County    36
# CA - San Mateo County       24
# CA - Santa Cruz             11
# Name: MAX_sum_agg, dtype: int64

# %% [markdown]
# #### PART1D - Largest claim difference for the largest number of procedures by providers
#
# We see largest claim difference for highest number of procedures for InpatientDRG for the follwing providers -
#
# - BAYONNE HOSPITAL CENTER, NJ          29
# - CROZER CHESTER MEDICAL CENTER, PA    12
# - HAHNEMANN UNIVERSITY HOSPITAL, PA     8

# %% [markdown]
# #### InpatientDRG
# Considering -
# - Average Covered Charges as Claims
# - Average Total Payments as Reimbursement

# %%
Medicare_Provider_Charge_In.head()
# Out:
#                              DRG Definition  Provider Id  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10001
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10005
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10006
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10011
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        10016
#
#                       Provider Name     Provider Street Address Provider City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER      1108 ROSS CLARK CIRCLE        DOTHAN
# 1     MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH          BOAZ
# 2    ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET      FLORENCE
# 3                 ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE    BIRMINGHAM
# 4     SHELBY BAPTIST MEDICAL CENTER     1000 FIRST STREET NORTH     ALABASTER
#
#   Provider State  Provider Zip Code  \
# 0             AL              36301
# 1             AL              35957
# 2             AL              35631
# 3             AL              35235
# 4             AL              35007
#
#   Hospital Referral Region (HRR) Description  Total Discharges  \
# 0                                AL - Dothan                91
# 1                            AL - Birmingham                14
# 2                            AL - Birmingham                24
# 3                            AL - Birmingham                25
# 4                            AL - Birmingham                18
#
#    Average Covered Charges  Average Total Payments  Average Medicare Payments
# 0              32963.07692             5777.241758                4763.736264
# 1              15131.85714             5787.571429                4976.714286
# 2              37560.37500             5434.958333                4453.791667
# 3              13998.28000             5417.560000                4129.160000
# 4              31633.27778             5658.333333                4851.444444

# %%
Medicare_IN_DRG = Medicare_Provider_Charge_In[['DRG Definition', 'Provider Name','Average Total Payments', 'Average Covered Charges' ]]

# %%
#Difference of claim and reimbursement
Medicare_IN_DRG['CLAIM_DIFF'] = Medicare_IN_DRG.apply(lambda x: x['Average Covered Charges'] - x['Average Total Payments'],axis =1)
# Out:
# C:\Users\yrp62\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Medicare_IN_DRG.head(5)
# Out:
#                              DRG Definition                     Provider Name  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC  SOUTHEAST ALABAMA MEDICAL CENTER
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC     MARSHALL MEDICAL CENTER SOUTH
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC    ELIZA COFFEE MEMORIAL HOSPITAL
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC                 ST VINCENT'S EAST
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC     SHELBY BAPTIST MEDICAL CENTER
#
#    Average Total Payments  Average Covered Charges    CLAIM_DIFF
# 0             5777.241758              32963.07692  27185.835162
# 1             5787.571429              15131.85714   9344.285711
# 2             5434.958333              37560.37500  32125.416667
# 3             5417.560000              13998.28000   8580.720000
# 4             5658.333333              31633.27778  25974.944447

# %%
#Finding the mean of Average Covered Charges for InpatientDRG by DRG Defination and Provider
Medicare_IN_AGG = pd.DataFrame(Medicare_IN_DRG[['DRG Definition', 'Provider Name', 'CLAIM_DIFF']].groupby(['DRG Definition', 'Provider Name']).agg('mean').add_suffix('_avg'))

# %%
Medicare_IN_AGG = Medicare_IN_AGG.reset_index()

# %%
Medicare_IN_AGG .head()
# Out:
#                              DRG Definition  \
# 0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
#
#                            Provider Name  CLAIM_DIFF_avg
# 0           ABBOTT NORTHWESTERN HOSPITAL    27026.166671
# 1        ABILENE REGIONAL MEDICAL CENTER    29293.857146
# 2             ABINGTON MEMORIAL HOSPITAL    33207.235299
# 3          ADENA REGIONAL MEDICAL CENTER    16247.499998
# 4  ADVENTIST LA GRANGE MEMORIAL HOSPITAL    30415.357141

# %%
#Finding the max for InpatientDRG DRG Definition
Medicare_IN_MAX = pd.DataFrame(Medicare_IN_AGG[['DRG Definition', 'CLAIM_DIFF_avg']].groupby(['DRG Definition']).agg('max').add_suffix('_max'))

# %%
Medicare_IN_MAX = Medicare_IN_MAX.reset_index()

# %%
Medicare_IN_MAX.head()
# Out:
#                                       DRG Definition  CLAIM_DIFF_avg_max
# 0           039 - EXTRACRANIAL PROCEDURES W/O CC/MCC        135377.61538
# 1  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...        122609.00000
# 2  064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...        214346.92103
# 3  065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...        144842.08333
# 4  066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...        109535.14290

# %%
#Merging The mean and max - will give side by side comparison of region having highest claim difference
Medicare_IN_MERGE = Medicare_IN_AGG.merge(Medicare_IN_MAX,on='DRG Definition', how='left')

# %%
Medicare_IN_MERGE = Medicare_IN_MERGE.reset_index()

# %%
Medicare_IN_MERGE.head()
# Out:
#    index                            DRG Definition  \
# 0      0  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 1      1  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 2      2  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 3      3  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 4      4  039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
#
#                            Provider Name  CLAIM_DIFF_avg  CLAIM_DIFF_avg_max
# 0           ABBOTT NORTHWESTERN HOSPITAL    27026.166671        135377.61538
# 1        ABILENE REGIONAL MEDICAL CENTER    29293.857146        135377.61538
# 2             ABINGTON MEMORIAL HOSPITAL    33207.235299        135377.61538
# 3          ADENA REGIONAL MEDICAL CENTER    16247.499998        135377.61538
# 4  ADVENTIST LA GRANGE MEMORIAL HOSPITAL    30415.357141        135377.61538

# %%
#function to get the max indicator
def difftyp(Medicare_IN_MERGE):
    if ((Medicare_IN_MERGE['CLAIM_DIFF_avg'] == Medicare_IN_MERGE['CLAIM_DIFF_avg_max'])):
        return 1
    elif ((Medicare_IN_MERGE['CLAIM_DIFF_avg'] > Medicare_IN_MERGE['CLAIM_DIFF_avg_max'])):
        return 1
    else:
        return 0

# %%
Medicare_IN_MERGE['MAX'] = Medicare_IN_MERGE.apply(difftyp, axis=1)

# %%
Medicare_IN_MERGE[Medicare_IN_MERGE['MAX'] == 1].head()
# Out:
#       index                                     DRG Definition  \
# 980     980           039 - EXTRACRANIAL PROCEDURES W/O CC/MCC
# 2048   2048  057 - DEGENERATIVE NERVOUS SYSTEM DISORDERS W/...
# 2533   2533  064 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...
# 3953   3953  065 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...
# 6514   6514  066 - INTRACRANIAL HEMORRHAGE OR CEREBRAL INFA...
#
#                                       Provider Name  CLAIM_DIFF_avg  \
# 980   UNIVERSITY OF CALIFORNIA DAVIS MEDICAL CENTER    135377.61538
# 2048                              STANFORD HOSPITAL    122609.00000
# 2533                         DOCTORS MEDICAL CENTER    214346.92103
# 3953                        BAYONNE HOSPITAL CENTER    144842.08333
# 6514                  HAHNEMANN UNIVERSITY HOSPITAL    109535.14290
#
#       CLAIM_DIFF_avg_max  MAX
# 980         135377.61538    1
# 2048        122609.00000    1
# 2533        214346.92103    1
# 3953        144842.08333    1
# 6514        109535.14290    1

# %%
#getting number of times a provider has max claim diff for max procudures
Medicare_IN_MERGE_GROUPED = pd.DataFrame(Medicare_IN_MERGE[['Provider Name','MAX']].groupby(['Provider Name']).agg('sum').add_suffix('_sum'),)

# %%
Medicare_IN_MERGE_GROUPED['MAX_sum'].nlargest(3)
# Out:
# Provider Name
# BAYONNE HOSPITAL CENTER          29
# CROZER CHESTER MEDICAL CENTER    12
# HAHNEMANN UNIVERSITY HOSPITAL     8
# Name: MAX_sum, dtype: int64

# %% [markdown]
# #### OutPatientsAPC

# %% [markdown]
# Considering -
# - Average Estimated Submitted Charges as Claims
# - Average Total Payments as Reimbursement

# %%
Medicare_Provider_Charge_Out.head()
# Out:
#                                         APC  Provider Id  \
# 0  0012 - Level I Debridement & Destruction        10029
# 1  0012 - Level I Debridement & Destruction        20024
# 2  0012 - Level I Debridement & Destruction        30064
# 3  0012 - Level I Debridement & Destruction        30088
# 4  0012 - Level I Debridement & Destruction        30111
#
#                                        Provider Name  \
# 0                EAST ALABAMA MEDICAL CENTER AND SNF
# 1                 CENTRAL PENINSULA GENERAL HOSPITAL
# 2   UNIVERSITY OF ARIZONA MEDICAL CTR-UNIVERSIT, THE
# 3                      BANNER BAYWOOD MEDICAL CENTER
# 4  UNIVERSITY OF ARIZONA MEDICAL CTR- SOUTH CAM, THE
#
#       Provider Street Address Provider City Provider State  Provider Zip Code  \
# 0      2000 PEPPERELL PARKWAY       OPELIKA             AL              36801
# 1          250 HOSPITAL PLACE      SOLDOTNA             AK              99669
# 2  1501 NORTH CAMPBELL AVENUE        TUCSON             AZ              85724
# 3    6644 EAST BAYWOOD AVENUE          MESA             AZ              85206
# 4           2800 EAST AJO WAY        TUCSON             AZ              85713
#
#   Hospital Referral Region (HRR) Description  Outpatient Services  \
# 0                            AL - Birmingham                   23
# 1                             AK - Anchorage                  994
# 2                                AZ - Tucson                 1765
# 3                                  AZ - Mesa                   20
# 4                                AZ - Tucson                   22
#
#    Average  Estimated Submitted Charges  Average Total Payments
# 0                             78.086957               21.910435
# 1                            149.589749               36.623853
# 2                             50.135411               14.541841
# 3                            112.400000               23.736000
# 4                            152.045455               16.569091

# %%
Medicare_Provider_Charge_Out.columns
# Out:
# Index(['APC', 'Provider Id', 'Provider Name', 'Provider Street Address',
#        'Provider City', 'Provider State', 'Provider Zip Code',
#        'Hospital Referral Region (HRR) Description', 'Outpatient Services',
#        'Average  Estimated Submitted Charges', 'Average Total Payments'],
#       dtype='object')

# %%
Medicare_Out_DRG = Medicare_Provider_Charge_Out[['APC', 'Provider Name', 'Average  Estimated Submitted Charges', 'Average Total Payments' ]]

# %%
#Difference of claim and reimbursement
Medicare_Out_DRG['CLAIM_DIFF'] = Medicare_Out_DRG.apply(lambda x: x['Average  Estimated Submitted Charges'] - x['Average Total Payments'],axis =1)
# Out:
# C:\Users\yrp62\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Medicare_Out_DRG.head(5)
# Out:
#                                         APC  \
# 0  0012 - Level I Debridement & Destruction
# 1  0012 - Level I Debridement & Destruction
# 2  0012 - Level I Debridement & Destruction
# 3  0012 - Level I Debridement & Destruction
# 4  0012 - Level I Debridement & Destruction
#
#                                        Provider Name  \
# 0                EAST ALABAMA MEDICAL CENTER AND SNF
# 1                 CENTRAL PENINSULA GENERAL HOSPITAL
# 2   UNIVERSITY OF ARIZONA MEDICAL CTR-UNIVERSIT, THE
# 3                      BANNER BAYWOOD MEDICAL CENTER
# 4  UNIVERSITY OF ARIZONA MEDICAL CTR- SOUTH CAM, THE
#
#    Average  Estimated Submitted Charges  Average Total Payments  CLAIM_DIFF
# 0                             78.086957               21.910435   56.176522
# 1                            149.589749               36.623853  112.965895
# 2                             50.135411               14.541841   35.593569
# 3                            112.400000               23.736000   88.664000
# 4                            152.045455               16.569091  135.476364

# %%
#Finding the mean of Average Covered Charges for InpatientDRG by DRG Defination and Provider
Medicare_Out_AGG = pd.DataFrame(Medicare_Out_DRG[['APC', 'Provider Name', 'CLAIM_DIFF']].groupby(['APC', 'Provider Name']).agg('mean').add_suffix('_avg'))

# %%
Medicare_Out_AGG = Medicare_Out_AGG.reset_index()

# %%
Medicare_Out_AGG .head()
# Out:
#                                         APC  \
# 0  0012 - Level I Debridement & Destruction
# 1  0012 - Level I Debridement & Destruction
# 2  0012 - Level I Debridement & Destruction
# 3  0012 - Level I Debridement & Destruction
# 4  0012 - Level I Debridement & Destruction
#
#                                        Provider Name  CLAIM_DIFF_avg
# 0                            ALTON MEMORIAL HOSPITAL       91.856818
# 1                                     ALTRU HOSPITAL        7.259495
# 2                         ARNOT OGDEN MEDICAL CENTER       98.893846
# 3                       AROOSTOOK MEDICAL CENTER,THE       16.975013
# 4  AVERA MCKENNAN HOSPITAL & UNIVERSITY HEALTH CE...       22.306715

# %%
#Finding the max for InpatientDRG DRG Definition
Medicare_Out_MAX = pd.DataFrame(Medicare_Out_AGG[['APC', 'CLAIM_DIFF_avg']].groupby(['APC']).agg('max').add_suffix('_max'))

# %%
Medicare_Out_MAX = Medicare_Out_MAX.reset_index()

# %%
Medicare_Out_MAX.head()
# Out:
#                                           APC  CLAIM_DIFF_avg_max
# 0    0012 - Level I Debridement & Destruction           827.44000
# 1   0013 - Level II Debridement & Destruction          5175.40000
# 2  0015 - Level III Debridement & Destruction          2980.73963
# 3             0019 - Level I Excision/ Biopsy         26073.80500
# 4            0020 - Level II Excision/ Biopsy         18362.75882

# %%
#Merging The mean and max - will give side by side comparison of region having highest claim difference
Medicare_Out_MERGE = Medicare_Out_AGG.merge(Medicare_Out_MAX,on='APC', how='left')

# %%
Medicare_Out_MERGE = Medicare_Out_MERGE.reset_index()

# %%
Medicare_Out_MERGE.head()
# Out:
#    index                                       APC  \
# 0      0  0012 - Level I Debridement & Destruction
# 1      1  0012 - Level I Debridement & Destruction
# 2      2  0012 - Level I Debridement & Destruction
# 3      3  0012 - Level I Debridement & Destruction
# 4      4  0012 - Level I Debridement & Destruction
#
#                                        Provider Name  CLAIM_DIFF_avg  \
# 0                            ALTON MEMORIAL HOSPITAL       91.856818
# 1                                     ALTRU HOSPITAL        7.259495
# 2                         ARNOT OGDEN MEDICAL CENTER       98.893846
# 3                       AROOSTOOK MEDICAL CENTER,THE       16.975013
# 4  AVERA MCKENNAN HOSPITAL & UNIVERSITY HEALTH CE...       22.306715
#
#    CLAIM_DIFF_avg_max
# 0              827.44
# 1              827.44
# 2              827.44
# 3              827.44
# 4              827.44

# %%
#function to get the max indicator
def difftyp(Medicare_Out_MERGE):
    if ((Medicare_Out_MERGE['CLAIM_DIFF_avg'] == Medicare_Out_MERGE['CLAIM_DIFF_avg_max'])):
        return 1
    elif ((Medicare_Out_MERGE['CLAIM_DIFF_avg'] > Medicare_Out_MERGE['CLAIM_DIFF_avg_max'])):
        return 1
    else:
        return 0

# %%
Medicare_Out_MERGE['MAX'] = Medicare_Out_MERGE.apply(difftyp, axis=1)

# %%
Medicare_Out_MERGE[Medicare_Out_MERGE['MAX'] == 1].head()
# Out:
#       index                                         APC  \
# 152     152    0012 - Level I Debridement & Destruction
# 1265   1265   0013 - Level II Debridement & Destruction
# 2703   2703  0015 - Level III Debridement & Destruction
# 3247   3247             0019 - Level I Excision/ Biopsy
# 4255   4255            0020 - Level II Excision/ Biopsy
#
#                              Provider Name  CLAIM_DIFF_avg  \
# 152          NEBRASKA ORTHOPAEDIC HOSPITAL       827.44000
# 1265                 RUSSELLVILLE HOSPITAL      5175.40000
# 2703               RESEARCH MEDICAL CENTER      2980.73963
# 3247     CENTINELA HOSPITAL MEDICAL CENTER     26073.80500
# 4255  ORANGE COAST MEMORIAL MEDICAL CENTER     18362.75882
#
#       CLAIM_DIFF_avg_max  MAX
# 152            827.44000    1
# 1265          5175.40000    1
# 2703          2980.73963    1
# 3247         26073.80500    1
# 4255         18362.75882    1

# %%
#getting number of times a provider has max claim diff for max procudures
Medicare_Out_MERGE_GROUPED = pd.DataFrame(Medicare_Out_MERGE[['Provider Name','MAX']].groupby(['Provider Name']).agg('sum').add_suffix('_sum'))

# %%
Medicare_Out_MERGE_GROUPED = Medicare_Out_MERGE_GROUPED.reset_index()

# %%
Medicare_Out_MERGE_GROUPED.head()
# Out:
#                      Provider Name  MAX_sum
# 0       ABBEVILLE GENERAL HOSPITAL        0
# 1     ABBOTT NORTHWESTERN HOSPITAL        0
# 2  ABILENE REGIONAL MEDICAL CENTER        0
# 3       ABINGTON MEMORIAL HOSPITAL        0
# 4                    ACMH HOSPITAL        0

# %%
Medicare_Out_MERGE_GROUPED['MAX_sum'].nlargest(3)
# Out:
# 327    2
# 484    2
# 799    2
# Name: MAX_sum, dtype: int64
